# %%
import os
import glob
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
% matplotlib inline

import scipy.sparse as sparse
from scipy.interpolate import interp1d
from scipy.signal import argrelextrema
from read_dsc import readDSC
from baseline import baseline_LSNF

# %%
files = glob.glob("*pBTTTketo*.txt")
files
# Out:
# ['DSC700926_pBTTTketo_10%a.txt', 'DSC700929_pBTTTketo_20%a.txt']

# %% [markdown]
# # Look at individual measurements:

# %%
# Import heating cycle
curve = readDSC(files[-3])[3] # there are four courves in each measurement

print("Date: " + str(curve.date) + "\n"
      + "Method: " + curve.method + "\n"
      + "Name: " + str(curve.name) + "\n"
      + "Weigth: " + str(curve.weight) + " [mg]" + "\n")

curve.plot(x="Tr [°C]",y="Value [mW]", figsize=(14,10),sort_columns=True,fontsize=18)
plt.title("DSC of PCE11 dropcasted at 100°C", fontsize=28)
plt.xlabel("Ts [°C]",fontsize=18)
plt.ylabel("Value [mW]",fontsize=18)
#plt.style.use('fivethirtyeight')
#plt.savefig("DPPTTT liquid cristal, ODCB 120°C.eps")
plt.show()

curve.head()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-12-050c4ab72be7> in <module>()
#       1 # Import heating cycle
# ----> 2 curve = readDSC(files[-3])[3] # there are four courves in each measurement
#       3
#       4 print("Date: " + str(curve.date) + "\n"
#       5       + "Method: " + curve.method + "\n"
#
# IndexError: list index out of range

# %%
len(curve)
# Out:
# 1500

# %% [markdown]
# # Read in all data for phase-diagram

# %%
data = pd.DataFrame()
metaData = pd.DataFrame(columns=["Attribute"], data=["Name", "Date", "Method", "Weigth"])

for i in files:
    data["Tr [°C]"] = readDSC(i)[3]["Tr [°C]"]#[60:-30] # cut edges from data
    data[i[:-4]] = readDSC(i)[3]["Value [mW]"]#[60:-30] # Otherwise baseline_LSNF(boundaries=False)
    metaData[i[:-4]] = [readDSC(i)[3].name, readDSC(i)[3].date,
                        readDSC(i)[3].method, readDSC(i)[3].weight]
data.head()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-5-86d266d7fabb> in <module>()
#       3
#       4 for i in files:
# ----> 5     data["Tr [°C]"] = readDSC(i)[3]["Tr [°C]"]#[60:-30] # cut edges from data
#       6     data[i[:-4]] = readDSC(i)[3]["Value [mW]"]#[60:-30] # Otherwise baseline_LSNF(boundaries=False)
#       7     metaData[i[:-4]] = [readDSC(i)[3].name, readDSC(i)[3].date,
#
# IndexError: list index out of range

# %%
metaData
# Out:
#   Attribute     DSC700694_pbtttRT
# 0      Name          ]1[DSC700694
# 1      Date            17.10.2016
# 2    Method  GMM_pBTTT_ketolactam
# 3    Weigth                   5.3

# %% [markdown]
# # Try to find baselines with algorithm:
# Inspect each plot !! and close windows with good fit. The remaining windows have to be redone by hand.

# %%
baseline_LSNF?

# %%
% matplotlib inline

c = data.columns
baselines = pd.DataFrame()
for i in range(1,len(c)):
    baselines[c[i]] = baseline_LSNF(data[c[i]], boundaries=False)
    

c = baselines.columns
for i in c:
    x = data["Tr [°C]"]
    y = data[i]
    yBase = baselines[i][0]
    xfreeze = x[list(baselines[i][1])]
    yfreeze = y[list(baselines[i][1])]
    
    plt.figure(figsize=(14,10))
    plt.plot(x, y, "-b", xfreeze, yfreeze, ".r", x, yBase, "--r")
    plt.title(i, fontsize=28)
    plt.xlabel("Ts [°C]",fontsize=18)
    plt.ylabel("Value [mW]",fontsize=18)
    plt.legend(["Value [mW]", "Smooth areas", "Fit baseline"], loc="best")
    plt.show()

baselines.head()
# Out:
#                                    DSC700694_pbtttRT
# 0  [4.03366200803, 4.03768839114, 4.04171477425, ...
# 1  [False, False, False, False, False, False, Fal...

# %% [markdown]
# # Cubic spline interpolation of the remaining baselines by hand

# %%
def cubicBase(xCol,yCol,valueList):
    # Interpolate
    mask = data[xCol].isin(baseLine)
    x = data[xCol][mask]
    y = data[yCol][mask]
    f = interp1d(x, y, kind='cubic', bounds_error=False) # New in version 0.17.0.: fill_value=“extrapolate”

    # Plot together
    xNew = data[xCol]
    yNew = f(data[xCol])

    plt.figure(figsize=(14,10))
    plt.plot(xNew,data[yCol], "-b", x, y, "or", xNew, yNew, "--r")
    plt.title(yCol, fontsize=28)
    plt.xlabel(xCol,fontsize=18)
    plt.ylabel(yCol,fontsize=18)
    plt.legend([yCol, "Points for interpolation", "Cubic spline interpolation"], loc="best")
    plt.show()
    
    # Store new baseline
    baselines[yCol][0] = yNew
    baselines[yCol][1] = [mask]

# %%
# Figure 1
xCol = "Tr [°C]"

yCol = "DSC700926_pBTTTketo_10%a.txt"
baseLine = [185,205,225,240,270,280,290,300] # Fill list with as much values as you like

cubicBase(xCol,yCol,baseLine)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /Users/giovannimariamatrone/anaconda/lib/python3.5/site-packages/pandas/indexes/base.py in get_loc(self, key, method, tolerance)
#    1944             try:
# -> 1945                 return self._engine.get_loc(key)
#    1946             except KeyError:
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:4154)()
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:4018)()
#
# pandas/hashtable.pyx in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:12368)()
#
# pandas/hashtable.pyx in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:12322)()
#
# KeyError: 'Tr [°C]'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-9-e7133a7185c5> in <module>()
#       5 baseLine = [185,205,225,240,270,280,290,300] # Fill list with as much values as you like
#       6
# ----> 7 cubicBase(xCol,yCol,baseLine)
#
# <ipython-input-6-63aef540a533> in cubicBase(xCol, yCol, valueList)
#       1 def cubicBase(xCol,yCol,valueList):
#       2     # Interpolate
# ----> 3     mask = data[xCol].isin(baseLine)
#       4     x = data[xCol][mask]
#       5     y = data[yCol][mask]
#
# /Users/giovannimariamatrone/anaconda/lib/python3.5/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    1995             return self._getitem_multilevel(key)
#    1996         else:
# -> 1997             return self._getitem_column(key)
#    1998
#    1999     def _getitem_column(self, key):
#
# /Users/giovannimariamatrone/anaconda/lib/python3.5/site-packages/pandas/core/frame.py in _getitem_column(self, key)
#    2002         # get column
#    2003         if self.columns.is_unique:
# -> 2004             return self._get_item_cache(key)
#    2005
#    2006         # duplicate columns & possible reduce dimensionality
#
# /Users/giovannimariamatrone/anaconda/lib/python3.5/site-packages/pandas/core/generic.py in _get_item_cache(self, item)
#    1348         res = cache.get(item)
#    1349         if res is None:
# -> 1350             values = self._data.get(item)
#    1351             res = self._box_item_values(item, values)
#    1352             cache[item] = res
#
# /Users/giovannimariamatrone/anaconda/lib/python3.5/site-packages/pandas/core/internals.py in get(self, item, fastpath)
#    3288
#    3289             if not isnull(item):
# -> 3290                 loc = self.items.get_loc(item)
#    3291             else:
#    3292                 indexer = np.arange(len(self.items))[isnull(self.items)]
#
# /Users/giovannimariamatrone/anaconda/lib/python3.5/site-packages/pandas/indexes/base.py in get_loc(self, key, method, tolerance)
#    1945                 return self._engine.get_loc(key)
#    1946             except KeyError:
# -> 1947                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    1948
#    1949         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:4154)()
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:4018)()
#
# pandas/hashtable.pyx in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:12368)()
#
# pandas/hashtable.pyx in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:12322)()
#
# KeyError: 'Tr [°C]'

# %% [markdown]
# # Substract baselines from data and save curves

# %%
c = baselines.columns
cleanData = pd.DataFrame(data["Tr [°C]"])

scanRate = 0.1667

for i in c:
    cleanData[i] = (data[i] - baselines[i][0]) / (metaData[i][3] * scanRate)

cleanData.to_csv("ICBA_till330" + "_cleanData.csv")
cleanData.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-f37008c11371> in <module>()
# ----> 1 c = baselines.columns
#       2 cleanData = pd.DataFrame(data["Tr [°C]"])
#       3
#       4 scanRate = 0.1667
#       5
#
# NameError: name 'baselines' is not defined

# %% [markdown]
# # Plot Curves together, normalized by weight

# %%
# Equidistant
% matplotlib inline
concentrations = [30, 40, 50, 60, 62.5, 65, 67.5, 70, 70, 72.5, 80, 90]

c = list(baselines.columns)
c.sort()

x = cleanData["Tr [°C]"]
offset = 0
plt.figure(figsize=(14,10))

for i in range(len(c)):
    offset += 2
    weight = metaData[c[i]][3]
    plt.plot(x, ((cleanData[c[i]] / weight) * 4 + offset))

plt.title("DSC 10°C/min of PCE11 dropcasted at 100°C", fontsize=28)
plt.xlabel("Ts [°C]", fontsize=18)
plt.yticks(range(2, (2*len(c)+2), 2), concentrations)
plt.ylabel("Different concentration [w%]", fontsize=18)
plt.xlim(120,300)
plt.savefig("DSC 0C_per_min of PCE11 dropcasted at 100°C" + "_equidistant" + ".pdf", format="pdf")
plt.show()

# %%
c
# Out:
# ['DSC700792_PCE11inICBA_60perc_to330C',
#  'DSC700793_PCE11inICBA_50perc_to330C',
#  'DSC700794_PCE11inICBA_40perc_to330C',
#  'PCE11_ICBA_30perc_RT_50to330C_DSC700816',
#  'PCE11_ICBA_60perc_RT_50to330C_DSC700815',
#  'PCE11_ICBA_625perc_RT_50to330C_DSC700814',
#  'PCE11_ICBA_65perc_RT_50to330C_DSC700813',
#  'PCE11_ICBA_675perc_RT_50to330C_DSC700812',
#  'PCE11_ICBA_70perc_RT_50to330C_DSC700811',
#  'PCE11_ICBA_75perc_RT_50to330C_DSC700810',
#  'PCE11_ICBA_80perc_RT_50to330C_DSC700809',
#  'PCE11_ICBA_90perc_RT_50to330DSC700808']

# %%
# Dependent on concentration
c = list(baselines.columns)
c.sort()

x = cleanData["Tr [°C]"]
offset = 0
plt.figure(figsize=(14,10))

for i in range(len(c)):
    offset = concentrations[i]
    weight = metaData[c[i]][3]
    plt.plot(x, ((cleanData[c[i]] / weight) * 30 + offset))

plt.title("DSC 10°C/min  of PCE11 dropcasted at 100°C", fontsize=28)
plt.xlabel("Ts [°C]", fontsize=18)
plt.yticks(concentrations)
plt.ylabel("Different concentration [w%]", fontsize=18)
plt.xlim(230,290)
plt.savefig("DSC 10C_per_min of PCE11 dropcasted at 100°C" + ".pdf", format="pdf")
plt.show()
